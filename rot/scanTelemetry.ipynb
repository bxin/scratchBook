# %% [markdown]
# xml version: b37190d

# %%
xmlFile = 'Rotator_Telemetry.xml'

# %%
import numpy as np
from astropy.time import Time
from datetime import timedelta, datetime
from lsst_efd_client import EfdClient

import pandas as pd

pd.set_option('display.max_rows', None)

# %%
client = EfdClient('summit_efd')
csc_index = 1

#start = Time('2020-11-03T11:41:30') #this is UTC
#end = start+timedelta(days=1)
end = Time(datetime.now())
end = Time('2020-11-05T14:30:30') #this is UTC
start = end - timedelta(seconds=5)
#import astropy
#astropy.utils.data.clear_download_cache()

# %%
fid = open(xmlFile)

topics = dict()
params = dict()
counts = dict()
lastT = dict()
values= dict()
nline = 0
for line in fid:
    if '<EFDB_Topic>' in line:
        i = line.find('<EFDB')
        topic = line[i+12:-14]
        t1, t2 = topic.split('_')
        dfa = await client.select_time_series('lsst.sal.%s.%s'%(t1,t2), '*', 
                                     (start-timedelta(seconds=37)).tai, (end-timedelta(seconds=37)).tai, csc_index)
    elif '<EFDB_Name>' in line:
        i = line.find('<EFDB')
        param = line[i+11:-13]
        nline+=1
        idx = '%d'%nline
    elif '<Count>' in line:
        i = line.find('<C')
        count = line[i+7:-9]
        print(topic, param,count)
        topics[idx] = topic
        params[idx] = param
        counts[idx] = count
        
        c = int(count)
        try:
            lastT[idx] = pd.to_datetime(dfa.private_sndStamp[-1], unit='s')
            if c == 1:
                values[idx] = dfa[param][-1]
            else:
                aa = [dfa['%s%d'%(param,i)][-1] for i in range(c)]
                values[idx] = np.mean(aa)
                if np.isnan(values[idx]):
                    print(aa)
        except:
            values[idx] = np.nan
    #if nline>7:
    #    break
print(nline)
fid.close()
# Out:
# Rotator_Electrical CopleyStatusWordDrive 2
# Rotator_Electrical CopleyLatchingFaultStatus 2
# Rotator_Application Demand 1
# Rotator_Application Position 1
# Rotator_Application Error 1
# Rotator_Motors Calibrated 2
# Rotator_Motors Raw 2
# 7

# %%
frame = {'Topic': topics, 'Name': params,
         'Count': counts, 'Last Timestamp (UTC)': lastT,
         'value (average)': values}
d = pd.DataFrame(frame)

# %%
d
# Out:
#                  Topic                       Name Count  \
# 1   Rotator_Electrical      CopleyStatusWordDrive     2
# 2   Rotator_Electrical  CopleyLatchingFaultStatus     2
# 3  Rotator_Application                     Demand     1
# 4  Rotator_Application                   Position     1
# 5  Rotator_Application                      Error     1
# 6       Rotator_Motors                 Calibrated     2
# 7       Rotator_Motors                        Raw     2
#
#            Last Timestamp (UTC)  value (average)
# 1 2020-11-05 14:30:29.962911844     5.687000e+03
# 2 2020-11-05 14:30:29.962911844     0.000000e+00
# 3 2020-11-05 14:30:29.960775137    -2.021510e+01
# 4 2020-11-05 14:30:29.960775137    -2.021542e+01
# 5 2020-11-05 14:30:29.960775137     3.167820e-04
# 6 2020-11-05 14:30:29.964777946    -2.020750e+01
# 7 2020-11-05 14:30:29.964777946     1.513020e+09

# %% [markdown]
# ### Pointing Component
# xml version: fa97b12

# %%
xmlFile = 'MTPtg_Telemetry.xml'

# %%
fid = open(xmlFile)

topics = dict()
params = dict()
counts = dict()
lastT = dict()
values= dict()
nline = 0
for line in fid:
    if '<EFDB_Topic>' in line:
        i = line.find('<EFDB')
        topic = line[i+12:-14]
        t1, t2 = topic.split('_')
        dfa = await client.select_time_series('lsst.sal.%s.%s'%(t1,t2), '*', 
                                     (start-timedelta(seconds=37)).tai, (end-timedelta(seconds=37)).tai, csc_index)
    elif '<EFDB_Name>' in line:
        i = line.find('<EFDB')
        param = line[i+11:-13]
        nline+=1
        idx = '%d'%nline
    elif '<Count>' in line:
        i = line.find('<C')
        count = line[i+7:-9]
        print(topic, param,count)
        topics[idx] = topic
        params[idx] = param
        counts[idx] = count
        
        c = int(count)
        try:
            lastT[idx] = pd.to_datetime(dfa.private_sndStamp[-1], unit='s')
            if c == 1:
                values[idx] = dfa[param][-1]
            else:
                aa = [dfa['%s%d'%(param,i)][-1] for i in range(c)]
                values[idx] = np.mean(aa)
                if np.isnan(values[idx]):
                    print(aa)
        except:
            values[idx] = np.nan
    #if nline>7:
    #    break
print(nline)
fid.close()
# Out:
# MTPtg_prospectiveTargetStatus timestamp 1
# MTPtg_prospectiveTargetStatus demandAz 1
# MTPtg_prospectiveTargetStatus demandEl 1
# MTPtg_prospectiveTargetStatus demandRot 1
# MTPtg_prospectiveTargetStatus demandAzVelocity 1
# MTPtg_prospectiveTargetStatus demandElVelocity 1
# MTPtg_prospectiveTargetStatus demandRotVelocity 1
# MTPtg_prospectiveTargetStatus ha 1
# MTPtg_prospectiveTargetStatus parAngle 1
# MTPtg_prospectiveTargetStatus airmass 1
# MTPtg_prospectiveTargetStatus demandRaString 1
# MTPtg_prospectiveTargetStatus demandDecString 1
# MTPtg_nextTargetStatus timestamp 1
# MTPtg_nextTargetStatus demandAz 1
# MTPtg_nextTargetStatus demandEl 1
# MTPtg_nextTargetStatus demandRot 1
# MTPtg_nextTargetStatus demandAzVelocity 1
# MTPtg_nextTargetStatus demandElVelocity 1
# MTPtg_nextTargetStatus demandRotVelocity 1
# MTPtg_nextTargetStatus ha 1
# MTPtg_nextTargetStatus parAngle 1
# MTPtg_nextTargetStatus airmass 1
# MTPtg_nextTargetStatus demandRaString 1
# MTPtg_nextTargetStatus demandDecString 1
# MTPtg_currentTimesToLimits timestamp 1
# MTPtg_currentTimesToLimits timeToAzlim 1
# MTPtg_currentTimesToLimits timeToRotlim 1
# MTPtg_currentTimesToLimits timeToObservable 1
# MTPtg_currentTimesToLimits timeToUnobservable 1
# MTPtg_currentTimesToLimits timeToBlindSpot 1
# MTPtg_currentTimesToLimits timeToBlindSpotExit 1
# MTPtg_currentTargetStatus timestamp 1
# MTPtg_currentTargetStatus demandAz 1
# MTPtg_currentTargetStatus demandEl 1
# MTPtg_currentTargetStatus demandRot 1
# MTPtg_currentTargetStatus demandAzVelocity 1
# MTPtg_currentTargetStatus demandElVelocity 1
# MTPtg_currentTargetStatus demandRotVelocity 1
# MTPtg_currentTargetStatus ha 1
# MTPtg_currentTargetStatus parAngle 1
# MTPtg_currentTargetStatus airmass 1
# MTPtg_currentTargetStatus demandRaString 1
# MTPtg_currentTargetStatus demandDecString 1
# MTPtg_guidingAndOffsets timestamp 1
# MTPtg_guidingAndOffsets iaa 1
# MTPtg_skyEnvironment moonriseTime 1
# MTPtg_skyEnvironment timeToMoonrise 1
# MTPtg_skyEnvironment moonsetTime 1
# MTPtg_skyEnvironment timeToMoonset 1
# MTPtg_skyEnvironment moonPhase 1
# MTPtg_skyEnvironment sunAltitude 1
# MTPtg_skyEnvironment moonAltitude 1
# MTPtg_skyEnvironment sunTargetDistance 1
# MTPtg_skyEnvironment moonTargetDistance 1
# 118

# %%
frame = {'Topic': topics, 'Name': params,
         'Count': counts, 'Last Timestamp (UTC)': lastT,
         'value (average)': values}
dp = pd.DataFrame(frame)

# %%
dp
# Out:
#                               Topic                     Name Count  \
# 1     MTPtg_prospectiveTargetStatus                timestamp     1
# 2     MTPtg_prospectiveTargetStatus                 demandAz     1
# 3     MTPtg_prospectiveTargetStatus                 demandEl     1
# 4     MTPtg_prospectiveTargetStatus                demandRot     1
# 5     MTPtg_prospectiveTargetStatus         demandAzVelocity     1
# 6     MTPtg_prospectiveTargetStatus         demandElVelocity     1
# 7     MTPtg_prospectiveTargetStatus        demandRotVelocity     1
# 8     MTPtg_prospectiveTargetStatus                       ha     1
# 9     MTPtg_prospectiveTargetStatus                 parAngle     1
# 10    MTPtg_prospectiveTargetStatus                  airmass     1
# 11    MTPtg_prospectiveTargetStatus           demandRaString     1
# 12    MTPtg_prospectiveTargetStatus          demandDecString     1
# 13           MTPtg_nextTargetStatus                timestamp     1
# 14           MTPtg_nextTargetStatus                 demandAz     1
# 15           MTPtg_nextTargetStatus                 demandEl     1
# 16           MTPtg_nextTargetStatus                demandRot     1
# 17           MTPtg_nextTargetStatus         demandAzVelocity     1
# 18           MTPtg_nextTargetStatus         demandElVelocity     1
# 19           MTPtg_nextTargetStatus        demandRotVelocity     1
# 20           MTPtg_nextTargetStatus                       ha     1
# 21           MTPtg_nextTargetStatus                 parAngle     1
# 22           MTPtg_nextTargetStatus                  airmass     1
# 23           MTPtg_nextTargetStatus           demandRaString     1
# 24           MTPtg_nextTargetStatus          demandDecString     1
# 25       MTPtg_currentTimesToLimits                timestamp     1
# 26       MTPtg_currentTimesToLimits              timeToAzlim     1
# 27       MTPtg_currentTimesToLimits             timeToRotlim     1
# 28       MTPtg_currentTimesToLimits         timeToObservable     1
# 29       MTPtg_currentTimesToLimits       timeToUnobservable     1
# 30       MTPtg_currentTimesToLimits          timeToBlindSpot     1
# 31       MTPtg_currentTimesToLimits      timeToBlindSpotExit     1
# 32        MTPtg_currentTargetStatus                timestamp     1
# 33        MTPtg_currentTargetStatus                 demandAz     1
# 34        MTPtg_currentTargetStatus                 demandEl     1
# 35        MTPtg_currentTargetStatus                demandRot     1
# 36        MTPtg_currentTargetStatus         demandAzVelocity     1
# 37        MTPtg_currentTargetStatus         demandElVelocity     1
# 38        MTPtg_currentTargetStatus        demandRotVelocity     1
# 39        MTPtg_currentTargetStatus                       ha     1
# 40        MTPtg_currentTargetStatus                 parAngle     1
# 41        MTPtg_currentTargetStatus                  airmass     1
# 42        MTPtg_currentTargetStatus           demandRaString     1
# 43        MTPtg_currentTargetStatus          demandDecString     1
# 44          MTPtg_guidingAndOffsets                timestamp     1
# 45          MTPtg_guidingAndOffsets                      iaa     1
# 46          MTPtg_guidingAndOffsets        guideControlState     1
# 47          MTPtg_guidingAndOffsets      guideAutoClearState     1
# 48          MTPtg_guidingAndOffsets                  guideGA     1
# 49          MTPtg_guidingAndOffsets                  guideGB     1
# 50          MTPtg_guidingAndOffsets             userOffsetRA     1
# 51          MTPtg_guidingAndOffsets            userOffsetDec     1
# 52          MTPtg_guidingAndOffsets          handsetOffsetRA     1
# 53          MTPtg_guidingAndOffsets         handsetOffsetDec     1
# 54          MTPtg_guidingAndOffsets         userCollOffsetCA     1
# 55          MTPtg_guidingAndOffsets         userCollOffsetCE     1
# 56          MTPtg_guidingAndOffsets      handsetCollOffsetCA     1
# 57          MTPtg_guidingAndOffsets      handsetCollOffsetCE     1
# 58          MTPtg_guidingAndOffsets          pointingOriginX     1
# 59          MTPtg_guidingAndOffsets          pointingOriginY     1
# 60          MTPtg_guidingAndOffsets     pointingOriginUserDX     1
# 61          MTPtg_guidingAndOffsets     pointingOriginUserDY     1
# 62          MTPtg_guidingAndOffsets  pointingOriginHandsetDX     1
# 63          MTPtg_guidingAndOffsets  pointingOriginHandsetDY     1
# 64   MTPtg_prospectiveTimesToLimits                timestamp     1
# 65   MTPtg_prospectiveTimesToLimits              timeToAzlim     1
# 66   MTPtg_prospectiveTimesToLimits             timeToRotlim     1
# 67   MTPtg_prospectiveTimesToLimits         timeToObservable     1
# 68   MTPtg_prospectiveTimesToLimits       timeToUnobservable     1
# 69   MTPtg_prospectiveTimesToLimits          timeToBlindSpot     1
# 70   MTPtg_prospectiveTimesToLimits      timeToBlindSpotExit     1
# 71                MTPtg_timeAndDate                      tai     1
# 72                MTPtg_timeAndDate                      utc     1
# 73                MTPtg_timeAndDate                      lst     1
# 74                MTPtg_timeAndDate                       jd     1
# 75                MTPtg_timeAndDate                      mjd     1
# 76                MTPtg_timeAndDate          localTimeString     1
# 77                MTPtg_timeAndDate                 leapSecs     1
# 78                MTPtg_timeAndDate                 timezone     1
# 79                MTPtg_mountStatus                timestamp     1
# 80                MTPtg_mountStatus                  mountRA     1
# 81                MTPtg_mountStatus                 mountDec     1
# 82                MTPtg_mountStatus            mountRAString     1
# 83                MTPtg_mountStatus           mountDecString     1
# 84                MTPtg_mountStatus       mountAzCurrentWrap     1
# 85                MTPtg_mountStatus      mountRotCurrentWrap     1
# 86                MTPtg_mountStatus             mountAzError     1
# 87                MTPtg_mountStatus             mountElError     1
# 88                MTPtg_mountStatus            mountRotError     1
# 89                MTPtg_mountStatus            mountAzString     1
# 90                MTPtg_mountStatus            mountElString     1
# 91                MTPtg_mountStatus           mountRotString     1
# 92                MTPtg_mountStatus              mountRotIAA     1
# 93                MTPtg_mountStatus              mountRotIPA     1
# 94          MTPtg_nextTimesToLimits                timestamp     1
# 95          MTPtg_nextTimesToLimits              timeToAzlim     1
# 96          MTPtg_nextTimesToLimits             timeToRotlim     1
# 97          MTPtg_nextTimesToLimits         timeToObservable     1
# 98          MTPtg_nextTimesToLimits       timeToUnobservable     1
# 99          MTPtg_nextTimesToLimits          timeToBlindSpot     1
# 100         MTPtg_nextTimesToLimits      timeToBlindSpotExit     1
# 101            MTPtg_skyEnvironment                timestamp     1
# 102            MTPtg_skyEnvironment               sunsetTime     1
# 103            MTPtg_skyEnvironment             timeToSunset     1
# 104            MTPtg_skyEnvironment          twilightEndTime     1
# 105            MTPtg_skyEnvironment        timeToTwilightEnd     1
# 106            MTPtg_skyEnvironment        twilightBeginTime     1
# 107            MTPtg_skyEnvironment      timeToTwilightBegin     1
# 108            MTPtg_skyEnvironment              sunriseTime     1
# 109            MTPtg_skyEnvironment            timeToSunrise     1
# 110            MTPtg_skyEnvironment             moonriseTime     1
# 111            MTPtg_skyEnvironment           timeToMoonrise     1
# 112            MTPtg_skyEnvironment              moonsetTime     1
# 113            MTPtg_skyEnvironment            timeToMoonset     1
# 114            MTPtg_skyEnvironment                moonPhase     1
# 115            MTPtg_skyEnvironment              sunAltitude     1
# 116            MTPtg_skyEnvironment             moonAltitude     1
# 117            MTPtg_skyEnvironment        sunTargetDistance     1
# 118            MTPtg_skyEnvironment       moonTargetDistance     1
#
#              Last Timestamp (UTC)        value (average)
# 1                             NaT                    NaN
# 2                             NaT                    NaN
# 3                             NaT                    NaN
# 4                             NaT                    NaN
# 5                             NaT                    NaN
# 6                             NaT                    NaN
# 7                             NaT                    NaN
# 8                             NaT                    NaN
# 9                             NaT                    NaN
# 10                            NaT                    NaN
# 11                            NaT                    NaN
# 12                            NaT                    NaN
# 13                            NaT                    NaN
# 14                            NaT                    NaN
# 15                            NaT                    NaN
# 16                            NaT                    NaN
# 17                            NaT                    NaN
# 18                            NaT                    NaN
# 19                            NaT                    NaN
# 20                            NaT                    NaN
# 21                            NaT                    NaN
# 22                            NaT                    NaN
# 23                            NaT                    NaN
# 24                            NaT                    NaN
# 25  2020-11-05 14:30:27.689624548                59158.6
# 26  2020-11-05 14:30:27.689624548                      1
# 27  2020-11-05 14:30:27.689624548                      1
# 28  2020-11-05 14:30:27.689624548                      1
# 29  2020-11-05 14:30:27.689624548                      1
# 30  2020-11-05 14:30:27.689624548                      1
# 31  2020-11-05 14:30:27.689624548                      1
# 32  2020-11-05 14:30:29.889431715                59158.6
# 33  2020-11-05 14:30:29.889431715            +0:00:00.00
# 34  2020-11-05 14:30:29.889431715            +0:00:00.00
# 35  2020-11-05 14:30:29.889431715           -20:12:55.71
# 36  2020-11-05 14:30:29.889431715                    NaN
# 37  2020-11-05 14:30:29.889431715                    NaN
# 38  2020-11-05 14:30:29.889431715                    NaN
# 39  2020-11-05 14:30:29.889431715
# 40  2020-11-05 14:30:29.889431715                      1
# 41  2020-11-05 14:30:29.889431715           6.93236e-310
# 42  2020-11-05 14:30:29.889431715
# 43  2020-11-05 14:30:29.889431715
# 44  2020-11-05 14:30:29.890650034                59158.6
# 45  2020-11-05 14:30:29.890650034                      0
# 46  2020-11-05 14:30:29.890650034                   True
# 47  2020-11-05 14:30:29.890650034                  False
# 48  2020-11-05 14:30:29.890650034                      0
# 49  2020-11-05 14:30:29.890650034                      0
# 50  2020-11-05 14:30:29.890650034                      0
